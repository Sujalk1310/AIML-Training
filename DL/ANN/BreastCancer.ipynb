# %%
import tensorflow as tf
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import seaborn as sns

# %%
le = LabelEncoder()
mm = MinMaxScaler()

# %%
data = pd.read_csv('/content/data.csv')

# %%
data
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
data.columns
data.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
data = data.drop(['id', 'Unnamed: 32'], axis = 1)
data.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
data['diagnosis'] = le.fit_transform(data['diagnosis'])
data.head()
# Out:
#    diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0          1        17.99  ...          0.4601                  0.11890
# 1          1        20.57  ...          0.2750                  0.08902
# 2          1        19.69  ...          0.3613                  0.08758
# 3          1        11.42  ...          0.6638                  0.17300
# 4          1        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
X = data.iloc[:, 1:]
Y = data.iloc[:, 0]

# %%
X = mm.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)
X_test.shape
# Out:
# (114, 30)

# %%
ann = Sequential()

# %%
ann.add(Dense(units = 16, activation = "relu"))
ann.add(Dense(units = 16, activation = "relu"))
ann.add(Dense(units = 1, activation = "sigmoid"))

# %%
ann.compile(loss = "binary_crossentropy", metrics = ['accuracy'], optimizer = 'adam')

# %%
ann.fit(X_train, Y_train, epochs = 50, validation_data= (X_test, Y_test))
# Out:
# Epoch 1/50
# 15/15 [==============================] - 2s 28ms/step - loss: 0.6773 - accuracy: 0.6857 - val_loss: 0.6606 - val_accuracy: 0.7807
# Epoch 2/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6508 - accuracy: 0.8110 - val_loss: 0.6394 - val_accuracy: 0.7632
# Epoch 3/50
# 15/15 [==============================] - 0s 11ms/step - loss: 0.6294 - accuracy: 0.8220 - val_loss: 0.6156 - val_accuracy: 0.8596
# Epoch 4/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6057 - accuracy: 0.8681 - val_loss: 0.5890 - val_accuracy: 0.8860
# Epoch 5/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5793 - accuracy: 0.8747 - val_loss: 0.5622 - val_accuracy: 0.8860
# Epoch 6/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5499 - accuracy: 0.8879 - val_loss: 0.5314 - val_accuracy: 0.8860
# Epoch 7/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5170 - accuracy: 0.8857 - val_loss: 0.4967 - val_accuracy: 0.8947
# Epoch 8/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4803 - accuracy: 0.8901 - val_loss: 0.4589 - val_accuracy: 0.8947
# Epoch 9/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4423 - accuracy: 0.8835 - val_loss: 0.4209 - val_accuracy: 0.8947
# Epoch 10/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.4046 - accuracy: 0.9077 - val_loss: 0.3830 - val_accuracy: 0.8947
# Epoch 11/50
# 15/15 [==============================] - 0s 21ms/step - loss: 0.3700 - accuracy: 0.9033 - val_loss: 0.3526 - val_accuracy: 0.9035
# Epoch 12/50
# 15/15 [==============================] - 0s 13ms/step - loss: 0.3387 - accuracy: 0.9187 - val_loss: 0.3226 - val_accuracy: 0.9035
# Epoch 13/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3109 - accuracy: 0.9121 - val_loss: 0.2968 - val_accuracy: 0.9123
# Epoch 14/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2846 - accuracy: 0.9253 - val_loss: 0.2746 - val_accuracy: 0.9035
# Epoch 15/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2627 - accuracy: 0.9253 - val_loss: 0.2581 - val_accuracy: 0.9123
# Epoch 16/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2439 - accuracy: 0.9253 - val_loss: 0.2398 - val_accuracy: 0.9123
# Epoch 17/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2297 - accuracy: 0.9341 - val_loss: 0.2264 - val_accuracy: 0.9035
# Epoch 18/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2123 - accuracy: 0.9275 - val_loss: 0.2158 - val_accuracy: 0.9123
# Epoch 19/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1989 - accuracy: 0.9341 - val_loss: 0.2060 - val_accuracy: 0.9123
# Epoch 20/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1874 - accuracy: 0.9407 - val_loss: 0.1982 - val_accuracy: 0.9123
# Epoch 21/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1805 - accuracy: 0.9407 - val_loss: 0.1915 - val_accuracy: 0.9123
# Epoch 22/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1761 - accuracy: 0.9319 - val_loss: 0.1853 - val_accuracy: 0.9211
# Epoch 23/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1622 - accuracy: 0.9473 - val_loss: 0.1804 - val_accuracy: 0.9035
# Epoch 24/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1553 - accuracy: 0.9495 - val_loss: 0.1750 - val_accuracy: 0.9035
# Epoch 25/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1480 - accuracy: 0.9516 - val_loss: 0.1706 - val_accuracy: 0.9386
# Epoch 26/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1440 - accuracy: 0.9495 - val_loss: 0.1672 - val_accuracy: 0.9211
# Epoch 27/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1375 - accuracy: 0.9582 - val_loss: 0.1633 - val_accuracy: 0.9298
# Epoch 28/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1330 - accuracy: 0.9582 - val_loss: 0.1596 - val_accuracy: 0.9386
# Epoch 29/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1285 - accuracy: 0.9604 - val_loss: 0.1566 - val_accuracy: 0.9386
# Epoch 30/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1242 - accuracy: 0.9582 - val_loss: 0.1538 - val_accuracy: 0.9386
# Epoch 31/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1203 - accuracy: 0.9648 - val_loss: 0.1511 - val_accuracy: 0.9386
# Epoch 32/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1163 - accuracy: 0.9626 - val_loss: 0.1479 - val_accuracy: 0.9474
# Epoch 33/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1123 - accuracy: 0.9648 - val_loss: 0.1453 - val_accuracy: 0.9474
# Epoch 34/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1090 - accuracy: 0.9692 - val_loss: 0.1424 - val_accuracy: 0.9561
# Epoch 35/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1054 - accuracy: 0.9670 - val_loss: 0.1406 - val_accuracy: 0.9561
# Epoch 36/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1032 - accuracy: 0.9692 - val_loss: 0.1391 - val_accuracy: 0.9561
# Epoch 37/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1000 - accuracy: 0.9714 - val_loss: 0.1365 - val_accuracy: 0.9649
# Epoch 38/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0979 - accuracy: 0.9670 - val_loss: 0.1360 - val_accuracy: 0.9649
# Epoch 39/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9736 - val_loss: 0.1332 - val_accuracy: 0.9649
# Epoch 40/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0932 - accuracy: 0.9692 - val_loss: 0.1320 - val_accuracy: 0.9649
# Epoch 41/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0938 - accuracy: 0.9692 - val_loss: 0.1311 - val_accuracy: 0.9649
# Epoch 42/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0893 - accuracy: 0.9758 - val_loss: 0.1308 - val_accuracy: 0.9737
# Epoch 43/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0874 - accuracy: 0.9648 - val_loss: 0.1286 - val_accuracy: 0.9649
# Epoch 44/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0847 - accuracy: 0.9758 - val_loss: 0.1281 - val_accuracy: 0.9737
# Epoch 45/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0839 - accuracy: 0.9758 - val_loss: 0.1286 - val_accuracy: 0.9737
# Epoch 46/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0823 - accuracy: 0.9736 - val_loss: 0.1264 - val_accuracy: 0.9737
# Epoch 47/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0810 - accuracy: 0.9824 - val_loss: 0.1262 - val_accuracy: 0.9649
# Epoch 48/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0795 - accuracy: 0.9780 - val_loss: 0.1250 - val_accuracy: 0.9737
# Epoch 49/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0789 - accuracy: 0.9824 - val_loss: 0.1250 - val_accuracy: 0.9737
# Epoch 50/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0771 - accuracy: 0.9802 - val_loss: 0.1247 - val_accuracy: 0.9737

# %%
pred_y = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
pred_y = (pred_y > 0.5)

# %%
cm = confusion_matrix(Y_test, pred_y)
cm
# Out:
# array([[66,  1],
#        [ 2, 45]])

# %%
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >
